# %% [markdown]
# # Setup - Install Libraries

# %%
# Run the following commands once, in order to install libraries - DO NOT Uncomment this line.

# Uncomment below lines
#
# !pip3 install --upgrade pip
# !pip install google-cloud-bigquery
# !pip install pandas-gbq -U
# !pip install db-dtypes
# !pip install packaging --upgrade
# Out:
# Requirement already satisfied: pip in c:\users\mouxios giorgos\python312\lib\site-packages (25.3)
# Requirement already satisfied: google-cloud-bigquery in c:\users\mouxios giorgos\python312\lib\site-packages (3.39.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.28.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (2.45.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (2.8.0)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery) (2.32.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.27.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\mouxios giorgos\python312\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\mouxios giorgos\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)
# Collecting pandas-gbq
#   Downloading pandas_gbq-0.32.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (72.1.0)
# Collecting db-dtypes<2.0.0,>=1.0.4 (from pandas-gbq)
#   Downloading db_dtypes-1.5.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (2.0.1)
# Requirement already satisfied: pandas<3.0.0,>=1.1.4 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (2.2.2)
# Collecting pyarrow>=4.0.0 (from pandas-gbq)
#   Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting pydata-google-auth>=1.5.0 (from pandas-gbq)
#   Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: psutil>=5.9.8 in c:\users\mouxios giorgos\appdata\roaming\python\python312\site-packages (from pandas-gbq) (7.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (2.28.1)
# Requirement already satisfied: google-auth>=2.14.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (2.45.0)
# Collecting google-auth-oauthlib>=0.7.0 (from pandas-gbq)
#   Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.20.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (3.39.0)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas-gbq) (25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.27.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth>=2.14.1->pandas-gbq) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth>=2.14.1->pandas-gbq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-auth>=2.14.1->pandas-gbq) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\mouxios giorgos\python312\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (4.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mouxios giorgos\python312\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\mouxios giorgos\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.14.1->pandas-gbq) (0.6.1)
# Collecting google-auth>=2.14.1 (from pandas-gbq)
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.7.0->pandas-gbq)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading pandas_gbq-0.32.0-py3-none-any.whl (46 kB)
# Downloading db_dtypes-1.5.0-py3-none-any.whl (18 kB)
# Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl (19 kB)
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/28.0 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/28.0 MB 5.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.4/28.0 MB 5.8 MB/s eta 0:00:05
#    ------ --------------------------------- 4.7/28.0 MB 5.8 MB/s eta 0:00:04
#    -------- ------------------------------- 6.0/28.0 MB 6.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 7.3/28.0 MB 6.0 MB/s eta 0:00:04
#    ------------ --------------------------- 8.7/28.0 MB 6.0 MB/s eta 0:00:04
#    ------------- -------------------------- 9.7/28.0 MB 6.0 MB/s eta 0:00:04
#    --------------- ------------------------ 11.0/28.0 MB 5.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.1/28.0 MB 5.9 MB/s eta 0:00:03
#    ------------------- -------------------- 13.6/28.0 MB 6.0 MB/s eta 0:00:03
#    --------------------- ------------------ 14.9/28.0 MB 6.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 16.3/28.0 MB 6.1 MB/s eta 0:00:02
#    ------------------------- -------------- 17.8/28.0 MB 6.1 MB/s eta 0:00:02
#    --------------------------- ------------ 19.1/28.0 MB 6.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.7/28.0 MB 6.2 MB/s eta 0:00:02
#    ------------------------------- -------- 22.0/28.0 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 23.6/28.0 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.6/28.0 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 25.4/28.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 26.0/28.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 26.5/28.0 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 27.0/28.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 5.5 MB/s  0:00:05
# Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl (15 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pyarrow, oauthlib, requests-oauthlib, google-auth, google-auth-oauthlib, db-dtypes, pydata-google-auth, pandas-gbq
#
#    ---------------------------------------- 0/8 [pyarrow]
#    ---------------------------------------- 0/8 [pyarrow]
#    ---------------------------------------- 0/8 [pyarrow]
#    ---------------------------------------- 0/8 [pyarrow]
#    ---------------------------------------- 0/8 [pyarrow]
#    ---------------------------------------- 0/8 [pyarrow]
#    ----- ---------------------------------- 1/8 [oauthlib]
#   Attempting uninstall: google-auth
#    ----- ---------------------------------- 1/8 [oauthlib]
#    --------------- ------------------------ 3/8 [google-auth]
#     Found existing installation: google-auth 2.45.0
#    --------------- ------------------------ 3/8 [google-auth]
#     Uninstalling google-auth-2.45.0:
#    --------------- ------------------------ 3/8 [google-auth]
#       Successfully uninstalled google-auth-2.45.0
#    --------------- ------------------------ 3/8 [google-auth]
#    --------------- ------------------------ 3/8 [google-auth]
#    ----------------------------------- ---- 7/8 [pandas-gbq]
#    ---------------------------------------- 8/8 [pandas-gbq]
#
# Successfully installed db-dtypes-1.5.0 google-auth-2.41.1 google-auth-oauthlib-1.2.3 oauthlib-3.3.1 pandas-gbq-0.32.0 pyarrow-22.0.0 pydata-google-auth-1.9.1 requests-oauthlib-2.0.0
# Requirement already satisfied: db-dtypes in c:\users\mouxios giorgos\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from db-dtypes) (2.0.1)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from db-dtypes) (25.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\mouxios giorgos\python312\lib\site-packages (from db-dtypes) (2.2.2)
# Requirement already satisfied: pyarrow>=13.0.0 in c:\users\mouxios giorgos\python312\lib\site-packages (from db-dtypes) (22.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mouxios giorgos\python312\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mouxios giorgos\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->db-dtypes) (1.16.0)
# Requirement already satisfied: packaging in c:\users\mouxios giorgos\python312\lib\site-packages (25.0)

# %% [markdown]
# # Import libraries

# %%
# Import libraries
from google.cloud import bigquery
import pandas as pd
from pandas_gbq import to_gbq
import os

print('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %%
# Set the environment variable for Google Cloud credentials
# Place the path in which the .json file is located.

# Example (if .json is located in the same directory with the notebook)
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "at-arch-416714-6f9900ec7.json"

# -- YOUR CODE GOES BELOW THIS LINE
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/Mouxios Giorgos/Downloads/Data Analytics/warm-influence-480112-t2-3027da7e0b9c.json" # Edit path
# -- YOUR CODE GOES ABOVE THIS LINE

# %%
# Set your Google Cloud project ID and BigQuery dataset details

# -- YOUR CODE GOES BELOW THIS

project_id = 'warm-influence-480112-t2' # Edit with your project id
dataset_id = 'staging_db' # Modify the necessary schema name: staging_db, reporting_db etc.
table_id = 'stg_store' # Modify the necessary table name: stg_customer, stg_city etc.

# -- YOUR CODE GOES ABOVE THIS LINE

# %% [markdown]
# # SQL Query

# %%
# Create a BigQuery client
client = bigquery.Client(project=project_id)

# -- YOUR CODE GOES BELOW THIS LINE

# Define your SQL query here
query ='''
with base as (
  select *
  from `warm-influence-480112-t2.pagila_production_mouxpublic.store`
),
final as (
  select
    store_id,
    manager_staff_id AS store_manager_staff_id,
    address_id AS store_address_id,
    last_update AS store_last_update
  FROM base
)
select * from final

'''

# -- YOUR CODE GOES ABOVE THIS LINE

# Execute the query and store the result in a dataframe
df = client.query(query).to_dataframe()

# Explore some records
df.head()
# Out:
# C:\Users\Mouxios Giorgos\python312\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    store_id  store_manager_staff_id  store_address_id  \
# 0         1                       1                 1
# 1         2                       2                 2
#
#           store_last_update
# 0 2022-02-15 09:57:12+00:00
# 1 2022-02-15 09:57:12+00:00

# %% [markdown]
# # Write to BigQuery

# %%
# Define the full table ID
full_table_id = f"{project_id}.{dataset_id}.{table_id}"

# -- YOUR CODE GOES BELOW THIS LINE
# Define table schema based on the project description

schema = [
    bigquery.SchemaField('store_id', 'INTEGER'),
    bigquery.SchemaField('store_manager_staff_id', 'INTEGER'),
    bigquery.SchemaField('store_address_id', 'INTEGER'),
    bigquery.SchemaField('store_last_update', 'DATETIME')
]


# -- YOUR CODE GOES ABOVE THIS LINE

# %%
# Create a BigQuery client
client = bigquery.Client(project=project_id)

# Check if the table exists
def table_exists(client, full_table_id):
    try:
        client.get_table(full_table_id)
        return True
    except Exception:
        return False

# Write the dataframe to the table (overwrite if it exists, create if it doesn't)
if table_exists(client, full_table_id):
    # If the table exists, overwrite it
    destination_table = f"{dataset_id}.{table_id}"
    # Write the dataframe to the table (overwrite if it exists)
    to_gbq(df, destination_table, project_id=project_id, if_exists='replace')
    print(f"Table {full_table_id} exists. Overwritten.")
else:
    # If the table does not exist, create it
    job_config = bigquery.LoadJobConfig(schema=schema)
    job = client.load_table_from_dataframe(df, full_table_id, job_config=job_config)
    job.result()  # Wait for the job to complete
    print(f"Table {full_table_id} did not exist. Created and data loaded.")
# Out:
# Table warm-influence-480112-t2.staging_db.stg_store did not exist. Created and data loaded.
